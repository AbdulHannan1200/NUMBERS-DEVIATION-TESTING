# %%
#Import Liberaries
import pickle 
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %%
# Import Lib
from random import seed
from random import randint
# seed random number generator
seed(1)

# %%
# Import Lib
import pandas as pd
# =     
import numpy as np

# %%
# Import Lib
from collections import Counter

# %%
# Import Lib
import operator

# %%
# Loading data file on which model was trained
df=pickle.load(open('bigdata.pkl','rb'))

# %%
# Loading ML Model saved in the same folder
model_lstm = load_model('model_lstm.h5')

# %%
# Custom Function which contains number which will be predicted and sethow many numbers of prediction you want
# return top 18 prediction for the number which was passed
def Predict_Classes(number,N = 18):
    output_lst = model_lstm.predict([number])
    output_lst = list(output_lst[0])
  
    res = sorted(range(len(output_lst)), key = lambda sub: output_lst[sub])[-N:] 

    
    return res

# %%
# Custom Function for working on simulation Algo A
def cond_A(user):
    Intervals_A = 1
    #counter_A = 0
    predict_list_Algo_A = list()
    df_lst=list()
    
    for i in range(user):
        value = randint(0, 36)
        print(i)
        print("Value: ",value)
        print("Value Presnet in Prediction List: ",predict_list_Algo_A)
        if i == 0:
            output = Predict_Classes(value)
            predict_list_Algo_A = output
            
        else:
            if value in predict_list_Algo_A:
                
                print("Number Found: ",value)
                print("Interval: ",Intervals_A)
                
                df_lst.append(Intervals_A)
                Intervals_A = 1
                
                output = Predict_Classes(value)
                
                
                print("Next Prediction List: ",output)
                predict_list_Algo_A = output

            else:
                Intervals_A = Intervals_A + 1
       
    print("Output: ",df_lst)
    return df_lst

# %%
# Custom Function for working on simulation Algo B
def cond_B(user):
    temp_lst = list()
    count_True = 0
    count_False = 0
    predict_list_Algo_B = list()
    
    for i in range(user):
        value = randint(0, 36)
        
        print("Value: ",value)
        print("Value Presnet in Prediction List: ",predict_list_Algo_B)
        if value in predict_list_Algo_B:
            count_True = count_True + 1
            print("Count True increase",count_True)
        else:
            count_False = count_False + 1
            print("Count False increase",count_False)
            
            
        output = Predict_Classes(value)
        print(i,value,output)
        predict_list_Algo_B = output 

    print(count_True)
    print(count_False)
    return count_True,count_False

# %%
# Custom Function for working on simulation Algo C
def cond_C(user):
    temp_lst = list()
    df_lst_C = list()
    Intervals_C = 1
    predict_list_Algo_C = list()
    
    for i in range(user):
        value = randint(0, 36)
        if i == 0:
            output = Predict_Classes(value)
            predict_list_Algo_C = output
            Intervals_C = 1
            
        else:
            print("Value: ",value)
            print("Intervals",Intervals_C)
            print("Value Presnet in Prediction List: ",predict_list_Algo_C)
            if value in predict_list_Algo_C:
                print("Intervals",Intervals_C)
                df_lst_C.append(Intervals_C)
                Intervals_C = 1
            else:
                Intervals_C = Intervals_C + 1
                print("Intervals Increase",Intervals_C)


            output = Predict_Classes(value)
            #print(i,value,output)
            predict_list_Algo_C = output 

   
    return df_lst_C

# %%
# Custom Function to check simulation how many simulation you want and which algo you wanna use
def Simulation_Input():
    
    user = int(input("Enter number of simulation you want: "))
    algo = input("Enter which algorithm you wanna use A, B or C: ").lower()
    
    if algo == 'a':
        df_lst = cond_A(user)
        dictionary=Counter(df_lst)
        dictionary=dict(dictionary)
        print("Dictionary Output: ",dictionary)
        sorted_d = dict(sorted(dictionary.items(), key=operator.itemgetter(0)))
        df = pd.DataFrame(sorted_d.items())
        df.columns=["Intervals","Number Of Count"]
        # create excel writer object
        writer = pd.ExcelWriter('output.xlsx')
        # write dataframe to excel
        df.to_excel(writer,'Sheet1')
        # save the excel
        writer.save()
        print('DataFrame is written successfully to Excel File.')
        
    elif algo == 'b':
        df = pd.DataFrame()
        count_True,count_False = cond_B(user)
        df.loc[0,'True Predicted'] = int(count_True)
        df.loc[0,'False Predicted'] = int(count_False)
        
        # create excel writer object
        writer = pd.ExcelWriter('output.xlsx')
        # write dataframe to excel
        df.to_excel(writer,'Sheet2')
        # save the excel
        writer.save()
        print('DataFrame is written successfully to Excel File.')
        print("Data Frame: ",df)
        
    elif algo == 'c':
        df_lst_C = cond_C(user)
        dictionary_C=Counter(df_lst_C)
        dictionary_C=dict(dictionary_C)
        print("Dictionary Output: ",dictionary_C)
        sorted_d_c = dict(sorted(dictionary_C.items(), key=operator.itemgetter(0)))
        df_c = pd.DataFrame(sorted_d_c.items())
        df_c.columns=["Intervals","Number Of Count"]
        
        # create excel writer object
        writer = pd.ExcelWriter('output.xlsx')
        # write dataframe to excel
        df_c.to_excel(writer,'Sheet3')
        # save the excel
        writer.save()
        print('DataFrame is written successfully to Excel File.')
        print("Data Frame: ",df_c)

# %%
# Calling Function
Simulation_Input()
# Out:
# Enter number of simulation you want: 200
# Enter which algorithm you wanna use A, B or C: a
# 0
# Value:  19
# Value Presnet in Prediction List:  []
# 1
# Value:  32
# Value Presnet in Prediction List:  [4, 34, 17, 3, 26, 35, 27, 6, 10, 9, 11, 5, 20, 23, 31, 14, 19, 30]
# 2
# Value:  20
# Value Presnet in Prediction List:  [4, 34, 17, 3, 26, 35, 27, 6, 10, 9, 11, 5, 20, 23, 31, 14, 19, 30]
# Number Found:  20
# Interval:  2
# Next Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 3
# Value:  34
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 4
# Value:  36
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# Number Found:  36
# Interval:  2
# Next Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 5
# Value:  35
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 6
# Value:  18
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 7
# Value:  33
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# Number Found:  33
# Interval:  3
# Next Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 8
# Value:  26
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 9
# Value:  34
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# Number Found:  34
# Interval:  2
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 10
# Value:  33
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  33
# Interval:  1
# Next Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 11
# Value:  26
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 12
# Value:  19
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 13
# Value:  28
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 14
# Value:  19
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# 15
# Value:  8
# Value Presnet in Prediction List:  [0, 29, 8, 13, 6, 31, 30, 11, 16, 32, 20, 12, 36, 21, 34, 25, 23, 17]
# Number Found:  8
# Interval:  5
# Next Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# 16
# Value:  32
# Value Presnet in Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# Number Found:  32
# Interval:  1
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 17
# Value:  28
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  28
# Interval:  1
# Next Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# 18
# Value:  8
# Value Presnet in Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# 19
# Value:  35
# Value Presnet in Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# 20
# Value:  10
# Value Presnet in Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# Number Found:  10
# Interval:  3
# Next Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 21
# Value:  16
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 22
# Value:  0
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 23
# Value:  27
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# Number Found:  27
# Interval:  3
# Next Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 24
# Value:  36
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 25
# Value:  2
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 26
# Value:  23
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 27
# Value:  26
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 28
# Value:  25
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 29
# Value:  18
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# Number Found:  18
# Interval:  6
# Next Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 30
# Value:  1
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 31
# Value:  5
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# Number Found:  5
# Interval:  2
# Next Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# 32
# Value:  5
# Value Presnet in Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# Number Found:  5
# Interval:  1
# Next Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# 33
# Value:  0
# Value Presnet in Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# 34
# Value:  24
# Value Presnet in Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# 35
# Value:  17
# Value Presnet in Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# Number Found:  17
# Interval:  3
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 36
# Value:  29
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 37
# Value:  17
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  17
# Interval:  2
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 38
# Value:  23
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  23
# Interval:  1
# Next Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# 39
# Value:  30
# Value Presnet in Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# 40
# Value:  21
# Value Presnet in Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# Number Found:  21
# Interval:  2
# Next Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# 41
# Value:  24
# Value Presnet in Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# 42
# Value:  29
# Value Presnet in Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# Number Found:  29
# Interval:  2
# Next Prediction List:  [29, 11, 0, 32, 13, 31, 7, 4, 19, 25, 36, 23, 10, 14, 30, 34, 6, 27]
# 43
# Value:  7
# Value Presnet in Prediction List:  [29, 11, 0, 32, 13, 31, 7, 4, 19, 25, 36, 23, 10, 14, 30, 34, 6, 27]
# Number Found:  7
# Interval:  1
# Next Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# 44
# Value:  30
# Value Presnet in Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# Number Found:  30
# Interval:  1
# Next Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 45
# Value:  22
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 46
# Value:  9
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 47
# Value:  26
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 48
# Value:  9
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 49
# Value:  1
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# Number Found:  1
# Interval:  5
# Next Prediction List:  [20, 15, 17, 5, 23, 14, 0, 7, 21, 3, 36, 34, 11, 32, 6, 27, 10, 25]
# 50
# Value:  11
# Value Presnet in Prediction List:  [20, 15, 17, 5, 23, 14, 0, 7, 21, 3, 36, 34, 11, 32, 6, 27, 10, 25]
# Number Found:  11
# Interval:  1
# Next Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# 51
# Value:  16
# Value Presnet in Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# 52
# Value:  23
# Value Presnet in Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# 53
# Value:  8
# Value Presnet in Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# 54
# Value:  18
# Value Presnet in Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# Number Found:  18
# Interval:  4
# Next Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 55
# Value:  26
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# Number Found:  26
# Interval:  1
# Next Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# 56
# Value:  16
# Value Presnet in Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# 57
# Value:  32
# Value Presnet in Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# Number Found:  32
# Interval:  2
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 58
# Value:  18
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  18
# Interval:  1
# Next Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 59
# Value:  26
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# Number Found:  26
# Interval:  1
# Next Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# 60
# Value:  17
# Value Presnet in Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# Number Found:  17
# Interval:  1
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 61
# Value:  27
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 62
# Value:  21
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 63
# Value:  31
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  31
# Interval:  3
# Next Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# 64
# Value:  13
# Value Presnet in Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# Number Found:  13
# Interval:  1
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 65
# Value:  31
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  31
# Interval:  1
# Next Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# 66
# Value:  25
# Value Presnet in Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# Number Found:  25
# Interval:  1
# Next Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# 67
# Value:  27
# Value Presnet in Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# Number Found:  27
# Interval:  1
# Next Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 68
# Value:  5
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 69
# Value:  4
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# Number Found:  4
# Interval:  2
# Next Prediction List:  [33, 21, 9, 25, 11, 32, 16, 5, 28, 20, 8, 31, 23, 34, 1, 6, 13, 17]
# 70
# Value:  8
# Value Presnet in Prediction List:  [33, 21, 9, 25, 11, 32, 16, 5, 28, 20, 8, 31, 23, 34, 1, 6, 13, 17]
# Number Found:  8
# Interval:  1
# Next Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# 71
# Value:  13
# Value Presnet in Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# 72
# Value:  9
# Value Presnet in Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# 73
# Value:  14
# Value Presnet in Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# Number Found:  14
# Interval:  3
# Next Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# 74
# Value:  1
# Value Presnet in Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# 75
# Value:  6
# Value Presnet in Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# Number Found:  6
# Interval:  2
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 76
# Value:  16
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 77
# Value:  9
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 78
# Value:  30
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  30
# Interval:  3
# Next Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 79
# Value:  6
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# Number Found:  6
# Interval:  1
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 80
# Value:  25
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  25
# Interval:  1
# Next Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# 81
# Value:  11
# Value Presnet in Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# 82
# Value:  0
# Value Presnet in Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# 83
# Value:  5
# Value Presnet in Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# 84
# Value:  27
# Value Presnet in Prediction List:  [17, 9, 26, 3, 31, 18, 13, 36, 21, 27, 23, 12, 14, 20, 22, 25, 34, 30]
# Number Found:  27
# Interval:  4
# Next Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 85
# Value:  3
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# 86
# Value:  35
# Value Presnet in Prediction List:  [1, 35, 29, 33, 32, 17, 14, 18, 4, 30, 27, 31, 13, 12, 6, 15, 8, 21]
# Number Found:  35
# Interval:  2
# Next Prediction List:  [31, 19, 26, 2, 5, 22, 17, 36, 33, 7, 14, 12, 20, 30, 21, 13, 27, 6]
# 87
# Value:  13
# Value Presnet in Prediction List:  [31, 19, 26, 2, 5, 22, 17, 36, 33, 7, 14, 12, 20, 30, 21, 13, 27, 6]
# Number Found:  13
# Interval:  1
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 88
# Value:  34
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 89
# Value:  27
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 90
# Value:  22
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 91
# Value:  3
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 92
# Value:  6
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  6
# Interval:  5
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 93
# Value:  35
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 94
# Value:  26
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 95
# Value:  7
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 96
# Value:  16
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 97
# Value:  17
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 98
# Value:  11
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  11
# Interval:  6
# Next Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# 99
# Value:  30
# Value Presnet in Prediction List:  [18, 6, 2, 1, 33, 14, 31, 5, 36, 24, 9, 32, 17, 20, 11, 30, 19, 29]
# Number Found:  30
# Interval:  1
# Next Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 100
# Value:  3
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# Number Found:  3
# Interval:  1
# Next Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# 101
# Value:  13
# Value Presnet in Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# Number Found:  13
# Interval:  1
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 102
# Value:  5
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 103
# Value:  24
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 104
# Value:  7
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 105
# Value:  28
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 106
# Value:  18
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  18
# Interval:  5
# Next Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 107
# Value:  32
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# Number Found:  32
# Interval:  1
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 108
# Value:  31
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 109
# Value:  25
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 110
# Value:  7
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 111
# Value:  30
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 112
# Value:  6
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  6
# Interval:  5
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 113
# Value:  9
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 114
# Value:  24
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 115
# Value:  12
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  12
# Interval:  3
# Next Prediction List:  [32, 4, 23, 10, 18, 3, 14, 26, 15, 13, 17, 22, 0, 28, 27, 36, 20, 6]
# 116
# Value:  10
# Value Presnet in Prediction List:  [32, 4, 23, 10, 18, 3, 14, 26, 15, 13, 17, 22, 0, 28, 27, 36, 20, 6]
# Number Found:  10
# Interval:  1
# Next Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 117
# Value:  33
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 118
# Value:  16
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 119
# Value:  26
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# 120
# Value:  34
# Value Presnet in Prediction List:  [7, 12, 21, 32, 23, 30, 13, 3, 20, 10, 36, 17, 11, 25, 6, 34, 27, 14]
# Number Found:  34
# Interval:  4
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 121
# Value:  18
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  18
# Interval:  1
# Next Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 122
# Value:  31
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# 123
# Value:  34
# Value Presnet in Prediction List:  [26, 12, 35, 16, 14, 15, 10, 36, 32, 7, 21, 6, 13, 34, 3, 27, 22, 5]
# Number Found:  34
# Interval:  2
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 124
# Value:  13
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  13
# Interval:  1
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 125
# Value:  21
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 126
# Value:  31
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  31
# Interval:  2
# Next Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# 127
# Value:  6
# Value Presnet in Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# Number Found:  6
# Interval:  1
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 128
# Value:  0
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 129
# Value:  22
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  22
# Interval:  2
# Next Prediction List:  [23, 12, 11, 22, 34, 31, 32, 3, 25, 5, 13, 36, 21, 20, 27, 30, 6, 14]
# 130
# Value:  17
# Value Presnet in Prediction List:  [23, 12, 11, 22, 34, 31, 32, 3, 25, 5, 13, 36, 21, 20, 27, 30, 6, 14]
# 131
# Value:  3
# Value Presnet in Prediction List:  [23, 12, 11, 22, 34, 31, 32, 3, 25, 5, 13, 36, 21, 20, 27, 30, 6, 14]
# Number Found:  3
# Interval:  2
# Next Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# 132
# Value:  34
# Value Presnet in Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# Number Found:  34
# Interval:  1
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 133
# Value:  28
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  28
# Interval:  1
# Next Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# 134
# Value:  19
# Value Presnet in Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# Number Found:  19
# Interval:  1
# Next Prediction List:  [4, 34, 17, 3, 26, 35, 27, 6, 10, 9, 11, 5, 20, 23, 31, 14, 19, 30]
# 135
# Value:  6
# Value Presnet in Prediction List:  [4, 34, 17, 3, 26, 35, 27, 6, 10, 9, 11, 5, 20, 23, 31, 14, 19, 30]
# Number Found:  6
# Interval:  1
# Next Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# 136
# Value:  14
# Value Presnet in Prediction List:  [10, 22, 11, 32, 23, 12, 3, 20, 13, 31, 21, 36, 25, 30, 27, 34, 6, 14]
# Number Found:  14
# Interval:  1
# Next Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# 137
# Value:  32
# Value Presnet in Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# Number Found:  32
# Interval:  1
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 138
# Value:  17
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  17
# Interval:  1
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 139
# Value:  17
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  17
# Interval:  1
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 140
# Value:  15
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 141
# Value:  26
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 142
# Value:  9
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 143
# Value:  8
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  8
# Interval:  4
# Next Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# 144
# Value:  16
# Value Presnet in Prediction List:  [0, 12, 32, 36, 20, 31, 28, 5, 16, 3, 4, 34, 19, 25, 21, 27, 6, 14]
# Number Found:  16
# Interval:  1
# Next Prediction List:  [29, 24, 23, 25, 12, 7, 20, 11, 34, 3, 32, 6, 13, 10, 27, 36, 30, 14]
# 145
# Value:  12
# Value Presnet in Prediction List:  [29, 24, 23, 25, 12, 7, 20, 11, 34, 3, 32, 6, 13, 10, 27, 36, 30, 14]
# Number Found:  12
# Interval:  1
# Next Prediction List:  [32, 4, 23, 10, 18, 3, 14, 26, 15, 13, 17, 22, 0, 28, 27, 36, 20, 6]
# 146
# Value:  26
# Value Presnet in Prediction List:  [32, 4, 23, 10, 18, 3, 14, 26, 15, 13, 17, 22, 0, 28, 27, 36, 20, 6]
# Number Found:  26
# Interval:  1
# Next Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# 147
# Value:  35
# Value Presnet in Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# 148
# Value:  3
# Value Presnet in Prediction List:  [3, 36, 28, 17, 23, 21, 27, 25, 11, 5, 10, 20, 32, 14, 34, 13, 30, 6]
# Number Found:  3
# Interval:  2
# Next Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# 149
# Value:  34
# Value Presnet in Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# Number Found:  34
# Interval:  1
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 150
# Value:  32
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  32
# Interval:  1
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 151
# Value:  9
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 152
# Value:  26
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 153
# Value:  17
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  17
# Interval:  3
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 154
# Value:  17
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  17
# Interval:  1
# Next Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# 155
# Value:  30
# Value Presnet in Prediction List:  [11, 20, 14, 8, 32, 10, 17, 34, 33, 30, 23, 22, 5, 18, 31, 25, 13, 6]
# Number Found:  30
# Interval:  1
# Next Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 156
# Value:  19
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 157
# Value:  17
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 158
# Value:  31
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 159
# Value:  13
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# Number Found:  13
# Interval:  4
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 160
# Value:  31
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  31
# Interval:  1
# Next Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# 161
# Value:  23
# Value Presnet in Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# Number Found:  23
# Interval:  1
# Next Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# 162
# Value:  30
# Value Presnet in Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# 163
# Value:  15
# Value Presnet in Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# 164
# Value:  21
# Value Presnet in Prediction List:  [33, 9, 8, 1, 23, 36, 12, 20, 22, 25, 21, 4, 34, 31, 14, 27, 6, 0]
# Number Found:  21
# Interval:  3
# Next Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# 165
# Value:  11
# Value Presnet in Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# 166
# Value:  11
# Value Presnet in Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# 167
# Value:  28
# Value Presnet in Prediction List:  [25, 4, 3, 5, 10, 17, 22, 20, 8, 29, 28, 21, 30, 14, 34, 19, 13, 6]
# Number Found:  28
# Interval:  3
# Next Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# 168
# Value:  34
# Value Presnet in Prediction List:  [0, 19, 10, 14, 11, 29, 25, 34, 27, 33, 9, 32, 13, 17, 20, 23, 6, 30]
# Number Found:  34
# Interval:  1
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 169
# Value:  9
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  9
# Interval:  1
# Next Prediction List:  [31, 36, 19, 1, 32, 11, 17, 13, 7, 20, 30, 34, 6, 21, 14, 27, 3, 16]
# 170
# Value:  3
# Value Presnet in Prediction List:  [31, 36, 19, 1, 32, 11, 17, 13, 7, 20, 30, 34, 6, 21, 14, 27, 3, 16]
# Number Found:  3
# Interval:  1
# Next Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# 171
# Value:  32
# Value Presnet in Prediction List:  [35, 21, 9, 25, 20, 11, 28, 23, 32, 8, 16, 1, 5, 31, 34, 6, 13, 17]
# Number Found:  32
# Interval:  1
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 172
# Value:  20
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  20
# Interval:  1
# Next Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 173
# Value:  33
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 174
# Value:  8
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 175
# Value:  13
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# Number Found:  13
# Interval:  3
# Next Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# 176
# Value:  20
# Value Presnet in Prediction List:  [13, 26, 0, 18, 12, 32, 25, 19, 30, 8, 11, 23, 31, 6, 20, 14, 9, 10]
# Number Found:  20
# Interval:  1
# Next Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# 177
# Value:  31
# Value Presnet in Prediction List:  [1, 11, 0, 29, 22, 31, 23, 5, 20, 7, 13, 10, 32, 30, 27, 36, 6, 14]
# Number Found:  31
# Interval:  1
# Next Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# 178
# Value:  30
# Value Presnet in Prediction List:  [1, 10, 3, 11, 23, 5, 20, 32, 36, 31, 25, 21, 13, 34, 30, 27, 14, 6]
# Number Found:  30
# Interval:  1
# Next Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 179
# Value:  21
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# 180
# Value:  7
# Value Presnet in Prediction List:  [29, 25, 4, 1, 20, 27, 36, 32, 7, 11, 5, 34, 3, 13, 10, 30, 14, 6]
# Number Found:  7
# Interval:  2
# Next Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# 181
# Value:  8
# Value Presnet in Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# 182
# Value:  8
# Value Presnet in Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# 183
# Value:  16
# Value Presnet in Prediction List:  [25, 3, 31, 1, 36, 17, 32, 34, 30, 21, 20, 16, 13, 14, 11, 5, 27, 6]
# Number Found:  16
# Interval:  3
# Next Prediction List:  [29, 24, 23, 25, 12, 7, 20, 11, 34, 3, 32, 6, 13, 10, 27, 36, 30, 14]
# 184
# Value:  14
# Value Presnet in Prediction List:  [29, 24, 23, 25, 12, 7, 20, 11, 34, 3, 32, 6, 13, 10, 27, 36, 30, 14]
# Number Found:  14
# Interval:  1
# Next Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# 185
# Value:  5
# Value Presnet in Prediction List:  [20, 2, 27, 0, 35, 25, 22, 15, 28, 7, 32, 16, 31, 19, 13, 21, 5, 6]
# Number Found:  5
# Interval:  1
# Next Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# 186
# Value:  34
# Value Presnet in Prediction List:  [20, 3, 17, 36, 11, 10, 23, 21, 31, 5, 32, 34, 25, 30, 27, 13, 14, 6]
# Number Found:  34
# Interval:  1
# Next Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 187
# Value:  3
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 188
# Value:  36
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 189
# Value:  11
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 190
# Value:  7
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 191
# Value:  14
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 192
# Value:  36
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 193
# Value:  12
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# 194
# Value:  32
# Value Presnet in Prediction List:  [33, 28, 18, 15, 29, 9, 17, 34, 27, 30, 22, 35, 10, 32, 21, 13, 5, 6]
# Number Found:  32
# Interval:  8
# Next Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# 195
# Value:  36
# Value Presnet in Prediction List:  [17, 32, 4, 21, 18, 29, 27, 8, 1, 10, 3, 5, 28, 36, 20, 23, 6, 13]
# Number Found:  36
# Interval:  1
# Next Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 196
# Value:  19
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 197
# Value:  27
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 198
# Value:  20
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# 199
# Value:  0
# Value Presnet in Prediction List:  [9, 31, 10, 32, 23, 30, 4, 29, 11, 21, 16, 5, 1, 33, 6, 22, 25, 14]
# Output:  [2, 2, 3, 2, 1, 5, 1, 1, 3, 3, 6, 2, 1, 3, 2, 1, 2, 2, 1, 1, 5, 1, 4, 1, 2, 1, 1, 1, 3, 1, 1, 1, 1, 2, 1, 3, 2, 3, 1, 1, 4, 2, 1, 5, 6, 1, 1, 1, 5, 1, 5, 3, 1, 4, 1, 2, 1, 2, 1, 2, 2, 1, 1, 1, 1, 1, 1, 1, 1, 4, 1, 1, 1, 2, 1, 1, 3, 1, 1, 4, 1, 1, 3, 3, 1, 1, 1, 1, 1, 3, 1, 1, 1, 2, 3, 1, 1, 1, 8, 1]
# Dictionary Output:  {2: 17, 3: 13, 1: 57, 5: 5, 6: 2, 4: 5, 8: 1}
# DataFrame is written successfully to Excel File.
